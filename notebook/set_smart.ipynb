# %%
import pandas as pd
import requests

# %%
# read API_KEY from secret variable in OS
import os
API_KEY = os.environ.get('API_KEY')

# %%
#get stock price using SET SMART API
#"https://www.setsmart.com/api/listed-company-api/eod-price-by-symbol?symbol=SCC&startDate=2023-01-01&endDate=2023-05-23&adjustedPriceFlag=Y" -H "api-key: API_KEY_HERE"
def get_stock_price(symbol, start_date, end_date, adjusted_price_flag='Y'):
    url = f'https://www.setsmart.com/api/listed-company-api/eod-price-by-symbol?symbol={symbol}&startDate={start_date}&endDate={end_date}&adjustedPriceFlag={adjusted_price_flag}'
    headers = {'api-key': API_KEY}
    r = requests.get(url, headers=headers)
    data = r.json()
    return data

# %%
data = get_stock_price('SCC', '2023-01-01', '2023-05-23')

# %%
#convert json to dataframe
df = pd.DataFrame(data)
df['date'] = pd.to_datetime(df['date'])

# %%
df.head().T
# Out:
#                                      0                    1  \
# date               2023-01-03 00:00:00  2023-01-04 00:00:00
# symbol                             SCC                  SCC
# securityType                        CS                   CS
# adjustedPriceFlag                    Y                    Y
# prior                            342.0                342.0
# open                             341.0                342.0
# high                             344.0                345.0
# low                              340.0                340.0
# close                            342.0                345.0
# average                     342.059286            343.08009
# aomVolume                    1666500.0            1559500.0
# aomValue                   570041800.0          535033400.0
# trVolume                           NaN                  NaN
# trValue                            NaN                  NaN
# totalVolume                  1667649.0            1560548.0
# totalValue                 570434876.0          535392235.0
# pe                                13.9                14.02
# pbv                               1.04                 1.05
# bvps                            329.61               329.61
# dividendYield                     5.41                 5.36
# marketCap               410400000000.0       414000000000.0
# volumeTurnover                0.138971             0.130046
#
#                                      2                    3  \
# date               2023-01-05 00:00:00  2023-01-06 00:00:00
# symbol                             SCC                  SCC
# securityType                        CS                   CS
# adjustedPriceFlag                    Y                    Y
# prior                            345.0                349.0
# open                             345.0                349.0
# high                             350.0                351.0
# low                              344.0                347.0
# close                            349.0                350.0
# average                     348.151706           349.795692
# aomVolume                    2734900.0            1471800.0
# aomValue                   952160100.0          514829300.0
# trVolume                       10900.0                  NaN
# trValue                      4051366.5                  NaN
# totalVolume                  2747959.0            1473891.0
# totalValue                 956962419.5          515560860.0
# pe                               14.18                14.22
# pbv                               1.06                 1.06
# bvps                            329.61               329.61
# dividendYield                      5.3                 5.29
# marketCap               418800000000.0       420000000000.0
# volumeTurnover                0.228997             0.122824
#
#                                      4
# date               2023-01-09 00:00:00
# symbol                             SCC
# securityType                        CS
# adjustedPriceFlag                    Y
# prior                            350.0
# open                             353.0
# high                             354.0
# low                              351.0
# close                            352.0
# average                     352.583638
# aomVolume                    1639200.0
# aomValue                   577955100.0
# trVolume                           NaN
# trValue                            NaN
# totalVolume                  1640824.0
# totalValue                 578527828.0
# pe                                14.3
# pbv                               1.07
# bvps                            329.61
# dividendYield                     5.26
# marketCap               422400000000.0
# volumeTurnover                0.136735

# %%
stock_list = ['ADVANC', 'AOT', 'AWC', 'BANPU', 'BBL', 'BDMS', 'BEM', 'BGRIM', 'BH', 'BTS', 'CBG', 'CENTEL', 'COM7', 'CPALL', 'CPF', 'CPN', 'CRC', 'DELTA', 'EA', 'EGCO', 'GLOBAL', 'GPSC', 'GULF', 'HMPRO', 'INTUCH', 'IVL', 'JMART', 'JMT', 'KBANK', 'KTB', 'KTC', 'LH', 'MINT', 'MTC', 'OR', 'OSP', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'SAWAD', 'SCB', 'SCC', 'SCGP', 'TIDLOR', 'TISCO', 'TOP', 'TRUE', 'TTB', 'TU']
# stock_list = ['ADVANC', 'AOT', 'AWC']
#load data from SET SMART API
#keep only date, symbol, close
#append all data to dataframe, with symbol as column name
START_DATE = '2021-01-01'
END_DATE = '2023-05-23'
for stock in stock_list:
    data = get_stock_price(stock, START_DATE, END_DATE)
    df = pd.DataFrame(data)
    df['date'] = pd.to_datetime(df['date'])
    df = df[['date', 'symbol', 'close']]
    df = df.rename(columns={'close': stock})
    df = df.drop(columns=['symbol'])
    df = df.set_index('date')
    if stock == 'ADVANC':
        df_all = df
    else:
        df_all = df_all.merge(df, how='left', on='date')

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 576 entries, 2021-01-04 to 2023-05-23
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ADVANC  576 non-null    float64
#  1   AOT     576 non-null    float64
#  2   AWC     576 non-null    float64
#  3   BANPU   576 non-null    float64
#  4   BBL     576 non-null    float64
#  5   BDMS    576 non-null    float64
#  6   BEM     576 non-null    float64
#  7   BGRIM   576 non-null    float64
#  8   BH      576 non-null    float64
#  9   BTS     576 non-null    float64
#  10  CBG     576 non-null    float64
#  11  CENTEL  576 non-null    float64
#  12  COM7    576 non-null    float64
#  13  CPALL   576 non-null    float64
#  14  CPF     576 non-null    float64
#  15  CPN     576 non-null    float64
#  16  CRC     576 non-null    float64
#  17  DELTA   576 non-null    float64
#  18  EA      576 non-null    float64
#  19  EGCO    576 non-null    float64
#  20  GLOBAL  576 non-null    float64
#  21  GPSC    576 non-null    float64
#  22  GULF    576 non-null    float64
#  23  HMPRO   576 non-null    float64
#  24  INTUCH  576 non-null    float64
#  25  IVL     576 non-null    float64
#  26  JMART   576 non-null    float64
#  27  JMT     576 non-null    float64
#  28  KBANK   576 non-null    float64
#  29  KTB     576 non-null    float64
#  30  KTC     576 non-null    float64
#  31  LH      576 non-null    float64
#  32  MINT    576 non-null    float64
#  33  MTC     576 non-null    float64
#  34  OR      548 non-null    float64
#  35  OSP     576 non-null    float64
#  36  PTT     576 non-null    float64
#  37  PTTEP   576 non-null    float64
#  38  PTTGC   576 non-null    float64
#  39  RATCH   576 non-null    float64
#  40  SAWAD   576 non-null    float64
#  41  SCB     259 non-null    float64
#  42  SCC     576 non-null    float64
#  43  SCGP    576 non-null    float64
#  44  TIDLOR  494 non-null    float64
#  45  TISCO   576 non-null    float64
#  46  TOP     576 non-null    float64
#  47  TRUE    52 non-null     float64
#  48  TTB     576 non-null    float64
#  49  TU      576 non-null    float64
# dtypes: float64(50)
# memory usage: 229.5 KB

# %%
df_all.to_parquet('data/stock_price.parquet')

# %%
data_f = get_stock_price('SCC', '2023-01-01', '2023-05-23')

# %%
data_f
# Out:
# [{'date': '2023-01-03',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 342.0,
#   'open': 341.0,
#   'high': 344.0,
#   'low': 340.0,
#   'close': 342.0,
#   'average': 342.0592859285929,
#   'aomVolume': 1666500.0,
#   'aomValue': 570041800.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1667649.0,
#   'totalValue': 570434876.0,
#   'pe': 13.9,
#   'pbv': 1.04,
#   'bvps': 329.61,
#   'dividendYield': 5.409999847412109,
#   'marketCap': 410400000000.0,
#   'volumeTurnover': 0.13897075},
#  {'date': '2023-01-04',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 342.0,
#   'open': 342.0,
#   'high': 345.0,
#   'low': 340.0,
#   'close': 345.0,
#   'average': 343.08008977236295,
#   'aomVolume': 1559500.0,
#   'aomValue': 535033400.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1560548.0,
#   'totalValue': 535392235.0,
#   'pe': 14.02,
#   'pbv': 1.05,
#   'bvps': 329.61,
#   'dividendYield': 5.360000133514404,
#   'marketCap': 414000000000.0,
#   'volumeTurnover': 0.13004566666666667},
#  {'date': '2023-01-05',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 345.0,
#   'open': 345.0,
#   'high': 350.0,
#   'low': 344.0,
#   'close': 349.0,
#   'average': 348.15170572964274,
#   'aomVolume': 2734900.0,
#   'aomValue': 952160100.0,
#   'trVolume': 10900.0,
#   'trValue': 4051366.5,
#   'totalVolume': 2747959.0,
#   'totalValue': 956962419.5,
#   'pe': 14.18,
#   'pbv': 1.06,
#   'bvps': 329.61,
#   'dividendYield': 5.300000190734863,
#   'marketCap': 418800000000.0,
#   'volumeTurnover': 0.22899658333333334},
#  {'date': '2023-01-06',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 349.0,
#   'open': 349.0,
#   'high': 351.0,
#   'low': 347.0,
#   'close': 350.0,
#   'average': 349.795692349504,
#   'aomVolume': 1471800.0,
#   'aomValue': 514829300.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1473891.0,
#   'totalValue': 515560860.0,
#   'pe': 14.22,
#   'pbv': 1.06,
#   'bvps': 329.61,
#   'dividendYield': 5.289999961853027,
#   'marketCap': 420000000000.0,
#   'volumeTurnover': 0.12282425},
#  {'date': '2023-01-09',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 350.0,
#   'open': 353.0,
#   'high': 354.0,
#   'low': 351.0,
#   'close': 352.0,
#   'average': 352.5836383601757,
#   'aomVolume': 1639200.0,
#   'aomValue': 577955100.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1640824.0,
#   'totalValue': 578527828.0,
#   'pe': 14.3,
#   'pbv': 1.07,
#   'bvps': 329.61,
#   'dividendYield': 5.260000228881836,
#   'marketCap': 422400000000.0,
#   'volumeTurnover': 0.13673533333333332},
#  {'date': '2023-01-10',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 352.0,
#   'open': 351.0,
#   'high': 358.0,
#   'low': 351.0,
#   'close': 358.0,
#   'average': 355.8287047841307,
#   'aomVolume': 3856500.0,
#   'aomValue': 1372253400.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 3859474.0,
#   'totalValue': 1373309127.0,
#   'pe': 14.55,
#   'pbv': 1.09,
#   'bvps': 329.61,
#   'dividendYield': 5.170000076293945,
#   'marketCap': 429600000000.0,
#   'volumeTurnover': 0.32162283333333336},
#  {'date': '2023-01-11',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 358.0,
#   'open': 359.0,
#   'high': 360.0,
#   'low': 355.0,
#   'close': 359.0,
#   'average': 357.52125751060737,
#   'aomVolume': 3511700.0,
#   'aomValue': 1255507400.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 3514153.0,
#   'totalValue': 1256383736.0,
#   'pe': 14.59,
#   'pbv': 1.09,
#   'bvps': 329.61,
#   'dividendYield': 5.150000095367432,
#   'marketCap': 430800000000.0,
#   'volumeTurnover': 0.29284608333333334},
#  {'date': '2023-01-12',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 359.0,
#   'open': 357.0,
#   'high': 358.0,
#   'low': 355.0,
#   'close': 356.0,
#   'average': 356.0149214080142,
#   'aomVolume': 2258500.0,
#   'aomValue': 804059700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2259894.0,
#   'totalValue': 804556248.0,
#   'pe': 14.47,
#   'pbv': 1.08,
#   'bvps': 329.61,
#   'dividendYield': 5.199999809265137,
#   'marketCap': 427200000000.0,
#   'volumeTurnover': 0.1883245},
#  {'date': '2023-01-13',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 356.0,
#   'open': 356.0,
#   'high': 358.0,
#   'low': 353.0,
#   'close': 355.0,
#   'average': 354.9469306526509,
#   'aomVolume': 3919400.0,
#   'aomValue': 1391179000.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 3920941.0,
#   'totalValue': 1391725976.0,
#   'pe': 14.43,
#   'pbv': 1.08,
#   'bvps': 329.61,
#   'dividendYield': 5.210000038146973,
#   'marketCap': 426000000000.0,
#   'volumeTurnover': 0.32674508333333335},
#  {'date': '2023-01-16',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 355.0,
#   'open': 355.0,
#   'high': 357.0,
#   'low': 354.0,
#   'close': 354.0,
#   'average': 354.57519606335535,
#   'aomVolume': 1300600.0,
#   'aomValue': 461160500.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1301432.0,
#   'totalValue': 461455553.0,
#   'pe': 14.38,
#   'pbv': 1.07,
#   'bvps': 329.61,
#   'dividendYield': 5.230000019073486,
#   'marketCap': 424800000000.0,
#   'volumeTurnover': 0.10845266666666667},
#  {'date': '2023-01-17',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 354.0,
#   'open': 354.0,
#   'high': 359.0,
#   'low': 354.0,
#   'close': 359.0,
#   'average': 357.3289282752902,
#   'aomVolume': 1929600.0,
#   'aomValue': 689501900.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1930796.0,
#   'totalValue': 689927907.0,
#   'pe': 14.59,
#   'pbv': 1.09,
#   'bvps': 329.61,
#   'dividendYield': 5.150000095367432,
#   'marketCap': 430800000000.0,
#   'volumeTurnover': 0.16089966666666666},
#  {'date': '2023-01-18',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 359.0,
#   'open': 359.0,
#   'high': 359.0,
#   'low': 355.0,
#   'close': 356.0,
#   'average': 356.17298265956885,
#   'aomVolume': 1897300.0,
#   'aomValue': 675767000.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1897911.0,
#   'totalValue': 675984677.0,
#   'pe': 14.47,
#   'pbv': 1.08,
#   'bvps': 329.61,
#   'dividendYield': 5.199999809265137,
#   'marketCap': 427200000000.0,
#   'volumeTurnover': 0.15815925},
#  {'date': '2023-01-19',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 356.0,
#   'open': 356.0,
#   'high': 358.0,
#   'low': 355.0,
#   'close': 356.0,
#   'average': 356.10962907455973,
#   'aomVolume': 1334500.0,
#   'aomValue': 475228300.0,
#   'trVolume': 286900.0,
#   'trValue': 102303300.0,
#   'totalVolume': 1622069.0,
#   'totalValue': 577770885.0,
#   'pe': 14.47,
#   'pbv': 1.08,
#   'bvps': 329.61,
#   'dividendYield': 5.199999809265137,
#   'marketCap': 427200000000.0,
#   'volumeTurnover': 0.13517541666666666},
#  {'date': '2023-01-20',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 356.0,
#   'open': 356.0,
#   'high': 357.0,
#   'low': 354.0,
#   'close': 355.0,
#   'average': 355.25119638826186,
#   'aomVolume': 1107500.0,
#   'aomValue': 393440700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1108188.0,
#   'totalValue': 393685137.0,
#   'pe': 14.43,
#   'pbv': 1.08,
#   'bvps': 329.61,
#   'dividendYield': 5.210000038146973,
#   'marketCap': 426000000000.0,
#   'volumeTurnover': 0.101499},
#  {'date': '2023-01-23',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 355.0,
#   'open': 353.0,
#   'high': 355.0,
#   'low': 352.0,
#   'close': 353.0,
#   'average': 353.1194424841214,
#   'aomVolume': 1133600.0,
#   'aomValue': 400296200.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1134321.0,
#   'totalValue': 400551179.0,
#   'pe': 14.34,
#   'pbv': 1.07,
#   'bvps': 329.61,
#   'dividendYield': 5.239999771118164,
#   'marketCap': 423600000000.0,
#   'volumeTurnover': 0.09876008333333333},
#  {'date': '2023-01-24',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 353.0,
#   'open': 354.0,
#   'high': 355.0,
#   'low': 348.0,
#   'close': 348.0,
#   'average': 350.12202048417134,
#   'aomVolume': 2148000.0,
#   'aomValue': 752062100.0,
#   'trVolume': 11500.0,
#   'trValue': 4002000.0,
#   'totalVolume': 2162446.0,
#   'totalValue': 757096469.0,
#   'pe': 14.14,
#   'pbv': 1.06,
#   'bvps': 329.61,
#   'dividendYield': 5.320000171661377,
#   'marketCap': 417600000000.0,
#   'volumeTurnover': 0.18947883333333335},
#  {'date': '2023-01-25',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 348.0,
#   'open': 345.0,
#   'high': 347.0,
#   'low': 343.0,
#   'close': 345.0,
#   'average': 344.5567086409032,
#   'aomVolume': 2303000.0,
#   'aomValue': 793514100.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2306895.0,
#   'totalValue': 794857869.0,
#   'pe': 14.02,
#   'pbv': 1.05,
#   'bvps': 329.61,
#   'dividendYield': 5.360000133514404,
#   'marketCap': 414000000000.0,
#   'volumeTurnover': 0.19938291666666666},
#  {'date': '2023-01-26',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 345.0,
#   'open': 335.0,
#   'high': 337.0,
#   'low': 332.0,
#   'close': 334.0,
#   'average': 334.77759208392627,
#   'aomVolume': 6043400.0,
#   'aomValue': 2023194900.0,
#   'trVolume': 349900.0,
#   'trValue': 117138682.24,
#   'totalVolume': 6401145.0,
#   'totalValue': 2142964260.24,
#   'pe': 13.57,
#   'pbv': 1.01,
#   'bvps': 329.61,
#   'dividendYield': 5.539999961853027,
#   'marketCap': 400800000000.0,
#   'volumeTurnover': 0.53532875},
#  {'date': '2023-01-27',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 334.0,
#   'open': 335.0,
#   'high': 341.0,
#   'low': 334.0,
#   'close': 340.0,
#   'average': 337.97373928029214,
#   'aomVolume': 2437100.0,
#   'aomValue': 823675800.0,
#   'trVolume': 24400.0,
#   'trValue': 8174000.0,
#   'totalVolume': 2463264.0,
#   'totalValue': 832447692.0,
#   'pe': 13.82,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.3499999046325684,
#   'marketCap': 408000000000.0,
#   'volumeTurnover': 0.20528866666666667},
#  {'date': '2023-01-30',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 340.0,
#   'open': 340.0,
#   'high': 344.0,
#   'low': 339.0,
#   'close': 344.0,
#   'average': 341.7386662766891,
#   'aomVolume': 1367600.0,
#   'aomValue': 467361800.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1368781.0,
#   'totalValue': 467764245.0,
#   'pe': 13.98,
#   'pbv': 1.04,
#   'bvps': 329.61,
#   'dividendYield': 2.3299999237060547,
#   'marketCap': 412800000000.0,
#   'volumeTurnover': 0.11406508333333333},
#  {'date': '2023-01-31',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 344.0,
#   'open': 341.0,
#   'high': 343.0,
#   'low': 336.0,
#   'close': 336.0,
#   'average': 338.5957654524376,
#   'aomVolume': 3277800.0,
#   'aomValue': 1109849200.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 3280199.0,
#   'totalValue': 1110665325.0,
#   'pe': 13.65,
#   'pbv': 1.02,
#   'bvps': 329.61,
#   'dividendYield': 2.380000114440918,
#   'marketCap': 403200000000.0,
#   'volumeTurnover': 0.2733499166666667},
#  {'date': '2023-02-01',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 336.0,
#   'open': 337.0,
#   'high': 343.0,
#   'low': 337.0,
#   'close': 342.0,
#   'average': 340.2334690025364,
#   'aomVolume': 1695300.0,
#   'aomValue': 576797800.0,
#   'trVolume': 383600.0,
#   'trValue': 128889600.0,
#   'totalVolume': 2080273.0,
#   'totalValue': 706154755.0,
#   'pe': 13.9,
#   'pbv': 1.04,
#   'bvps': 329.61,
#   'dividendYield': 2.3399999141693115,
#   'marketCap': 410400000000.0,
#   'volumeTurnover': 0.17335608333333333},
#  {'date': '2023-02-02',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 342.0,
#   'open': 343.0,
#   'high': 343.0,
#   'low': 338.0,
#   'close': 338.0,
#   'average': 339.0525630829296,
#   'aomVolume': 1383100.0,
#   'aomValue': 468943600.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1384734.0,
#   'totalValue': 469498209.0,
#   'pe': 13.73,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 405600000000.0,
#   'volumeTurnover': 0.1153945},
#  {'date': '2023-02-03',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 338.0,
#   'open': 337.0,
#   'high': 340.0,
#   'low': 337.0,
#   'close': 338.0,
#   'average': 338.1467570330544,
#   'aomVolume': 2641100.0,
#   'aomValue': 893079400.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2642472.0,
#   'totalValue': 893543987.0,
#   'pe': 13.73,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 405600000000.0,
#   'volumeTurnover': 0.220206},
#  {'date': '2023-02-06',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 338.0,
#   'open': 337.0,
#   'high': 339.0,
#   'low': 336.0,
#   'close': 336.0,
#   'average': 337.1636749867233,
#   'aomVolume': 941500.0,
#   'aomValue': 317439600.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 942996.0,
#   'totalValue': 317944926.0,
#   'pe': 13.65,
#   'pbv': 1.02,
#   'bvps': 329.61,
#   'dividendYield': 2.380000114440918,
#   'marketCap': 403200000000.0,
#   'volumeTurnover': 0.08179133333333333},
#  {'date': '2023-02-07',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 336.0,
#   'open': 337.0,
#   'high': 339.0,
#   'low': 336.0,
#   'close': 338.0,
#   'average': 337.79095407587465,
#   'aomVolume': 2303800.0,
#   'aomValue': 778202800.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2304687.0,
#   'totalValue': 778502554.0,
#   'pe': 13.73,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 405600000000.0,
#   'volumeTurnover': 0.19234058333333334},
#  {'date': '2023-02-08',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 338.0,
#   'open': 338.0,
#   'high': 340.0,
#   'low': 337.0,
#   'close': 338.0,
#   'average': 338.57307728691706,
#   'aomVolume': 2114200.0,
#   'aomValue': 715811200.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2114967.0,
#   'totalValue': 716071182.0,
#   'pe': 13.73,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 405600000000.0,
#   'volumeTurnover': 0.17624725},
#  {'date': '2023-02-09',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 338.0,
#   'open': 338.0,
#   'high': 339.0,
#   'low': 335.0,
#   'close': 338.0,
#   'average': 337.28450086339666,
#   'aomVolume': 2142700.0,
#   'aomValue': 722699500.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2143357.0,
#   'totalValue': 722920831.0,
#   'pe': 13.73,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 405600000000.0,
#   'volumeTurnover': 0.17861308333333334},
#  {'date': '2023-02-10',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 338.0,
#   'open': 337.0,
#   'high': 340.0,
#   'low': 337.0,
#   'close': 338.0,
#   'average': 338.42381300983055,
#   'aomVolume': 1912400.0,
#   'aomValue': 647201700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1913324.0,
#   'totalValue': 647514562.0,
#   'pe': 13.73,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 405600000000.0,
#   'volumeTurnover': 0.159652},
#  {'date': '2023-02-13',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 338.0,
#   'open': 338.0,
#   'high': 339.0,
#   'low': 335.0,
#   'close': 335.0,
#   'average': 336.6324586327929,
#   'aomVolume': 1794900.0,
#   'aomValue': 604221600.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1796324.0,
#   'totalValue': 604701307.0,
#   'pe': 13.61,
#   'pbv': 1.02,
#   'bvps': 329.61,
#   'dividendYield': 2.390000104904175,
#   'marketCap': 402000000000.0,
#   'volumeTurnover': 0.14969366666666667},
#  {'date': '2023-02-14',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 335.0,
#   'open': 336.0,
#   'high': 341.0,
#   'low': 336.0,
#   'close': 341.0,
#   'average': 339.360992481203,
#   'aomVolume': 3325000.0,
#   'aomValue': 1128375300.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 3326298.0,
#   'totalValue': 1128814807.0,
#   'pe': 13.86,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.3499999046325684,
#   'marketCap': 409200000000.0,
#   'volumeTurnover': 0.2771915},
#  {'date': '2023-02-15',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 341.0,
#   'open': 338.0,
#   'high': 340.0,
#   'low': 338.0,
#   'close': 338.0,
#   'average': 338.9205723298783,
#   'aomVolume': 887600.0,
#   'aomValue': 300825900.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 888346.0,
#   'totalValue': 301078701.0,
#   'pe': 13.73,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 405600000000.0,
#   'volumeTurnover': 0.07402883333333334},
#  {'date': '2023-02-16',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 338.0,
#   'open': 338.0,
#   'high': 340.0,
#   'low': 337.0,
#   'close': 340.0,
#   'average': 339.3670141882888,
#   'aomVolume': 1275700.0,
#   'aomValue': 432930500.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1276381.0,
#   'totalValue': 433160707.0,
#   'pe': 13.82,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.3499999046325684,
#   'marketCap': 408000000000.0,
#   'volumeTurnover': 0.10636508333333333},
#  {'date': '2023-02-17',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 340.0,
#   'open': 339.0,
#   'high': 340.0,
#   'low': 337.0,
#   'close': 340.0,
#   'average': 339.0954012823347,
#   'aomVolume': 904600.0,
#   'aomValue': 306745700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 905325.0,
#   'totalValue': 306990838.0,
#   'pe': 13.82,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.3499999046325684,
#   'marketCap': 408000000000.0,
#   'volumeTurnover': 0.07544375},
#  {'date': '2023-02-20',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 340.0,
#   'open': 341.0,
#   'high': 341.0,
#   'low': 338.0,
#   'close': 339.0,
#   'average': 339.5676872713268,
#   'aomVolume': 519300.0,
#   'aomValue': 176337500.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 520070.0,
#   'totalValue': 176598859.0,
#   'pe': 13.77,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.359999895095825,
#   'marketCap': 406800000000.0,
#   'volumeTurnover': 0.043339166666666665},
#  {'date': '2023-02-21',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 339.0,
#   'open': 339.0,
#   'high': 342.0,
#   'low': 338.0,
#   'close': 340.0,
#   'average': 340.1491578399028,
#   'aomVolume': 1151800.0,
#   'aomValue': 391783800.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1152516.0,
#   'totalValue': 392028593.0,
#   'pe': 13.82,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.3499999046325684,
#   'marketCap': 408000000000.0,
#   'volumeTurnover': 0.096043},
#  {'date': '2023-02-22',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 340.0,
#   'open': 340.0,
#   'high': 340.0,
#   'low': 335.0,
#   'close': 336.0,
#   'average': 336.9729990874443,
#   'aomVolume': 1862900.0,
#   'aomValue': 627747000.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1864147.0,
#   'totalValue': 628167638.0,
#   'pe': 13.65,
#   'pbv': 1.02,
#   'bvps': 329.61,
#   'dividendYield': 2.380000114440918,
#   'marketCap': 403200000000.0,
#   'volumeTurnover': 0.15534558333333334},
#  {'date': '2023-02-23',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 336.0,
#   'open': 336.0,
#   'high': 339.0,
#   'low': 336.0,
#   'close': 338.0,
#   'average': 337.1875171593301,
#   'aomVolume': 1092700.0,
#   'aomValue': 368444800.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1093452.0,
#   'totalValue': 368697812.0,
#   'pe': 13.73,
#   'pbv': 1.03,
#   'bvps': 329.61,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 405600000000.0,
#   'volumeTurnover': 0.091121},
#  {'date': '2023-02-24',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 338.0,
#   'open': 337.0,
#   'high': 338.0,
#   'low': 330.0,
#   'close': 331.0,
#   'average': 332.0693505268124,
#   'aomVolume': 1907700.0,
#   'aomValue': 633488700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1912157.0,
#   'totalValue': 634971245.0,
#   'pe': 18.58,
#   'pbv': 1.06,
#   'bvps': 311.88,
#   'dividendYield': 2.4200000762939453,
#   'marketCap': 397200000000.0,
#   'volumeTurnover': 0.15934641666666666},
#  {'date': '2023-02-27',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 331.0,
#   'open': 330.0,
#   'high': 332.0,
#   'low': 328.0,
#   'close': 328.0,
#   'average': 329.24715508832776,
#   'aomVolume': 1845400.0,
#   'aomValue': 607592700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1848070.0,
#   'totalValue': 608473567.0,
#   'pe': 18.41,
#   'pbv': 1.05,
#   'bvps': 311.88,
#   'dividendYield': 2.440000057220459,
#   'marketCap': 393600000000.0,
#   'volumeTurnover': 0.15400583333333334},
#  {'date': '2023-02-28',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 328.0,
#   'open': 329.0,
#   'high': 331.0,
#   'low': 326.0,
#   'close': 327.0,
#   'average': 327.45993298615315,
#   'aomVolume': 2477100.0,
#   'aomValue': 811151000.0,
#   'trVolume': 44500.0,
#   'trValue': 14729500.0,
#   'totalVolume': 2524806.0,
#   'totalValue': 826931788.0,
#   'pe': 18.35,
#   'pbv': 1.05,
#   'bvps': 311.88,
#   'dividendYield': 2.450000047683716,
#   'marketCap': 392400000000.0,
#   'volumeTurnover': 0.2104005},
#  {'date': '2023-03-01',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 327.0,
#   'open': 329.0,
#   'high': 329.0,
#   'low': 321.0,
#   'close': 321.0,
#   'average': 323.75776299612244,
#   'aomVolume': 3172100.0,
#   'aomValue': 1026992000.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 3177104.0,
#   'totalValue': 1028614251.0,
#   'pe': 18.01,
#   'pbv': 1.03,
#   'bvps': 311.88,
#   'dividendYield': 2.490000009536743,
#   'marketCap': 385200000000.0,
#   'volumeTurnover': 0.26475866666666664},
#  {'date': '2023-03-02',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 321.0,
#   'open': 322.0,
#   'high': 332.0,
#   'low': 322.0,
#   'close': 330.0,
#   'average': 329.1922147182695,
#   'aomVolume': 4012700.0,
#   'aomValue': 1320949600.0,
#   'trVolume': 600.0,
#   'trValue': 198000.0,
#   'totalVolume': 4015702.0,
#   'totalValue': 1321936341.0,
#   'pe': 18.52,
#   'pbv': 1.06,
#   'bvps': 311.88,
#   'dividendYield': 2.4200000762939453,
#   'marketCap': 396000000000.0,
#   'volumeTurnover': 0.33464183333333336},
#  {'date': '2023-03-03',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 330.0,
#   'open': 332.0,
#   'high': 333.0,
#   'low': 328.0,
#   'close': 328.0,
#   'average': 329.59701694915253,
#   'aomVolume': 1475000.0,
#   'aomValue': 486155600.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1475661.0,
#   'totalValue': 486373743.0,
#   'pe': 18.41,
#   'pbv': 1.05,
#   'bvps': 311.88,
#   'dividendYield': 2.440000057220459,
#   'marketCap': 393600000000.0,
#   'volumeTurnover': 0.12297175},
#  {'date': '2023-03-07',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 328.0,
#   'open': 332.0,
#   'high': 337.0,
#   'low': 332.0,
#   'close': 334.0,
#   'average': 335.06937672249313,
#   'aomVolume': 3773600.0,
#   'aomValue': 1264417800.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 3774900.0,
#   'totalValue': 1264853710.0,
#   'pe': 18.74,
#   'pbv': 1.07,
#   'bvps': 311.88,
#   'dividendYield': 2.4000000953674316,
#   'marketCap': 400800000000.0,
#   'volumeTurnover': 0.31459166666666666},
#  {'date': '2023-03-08',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 334.0,
#   'open': 330.0,
#   'high': 333.0,
#   'low': 327.0,
#   'close': 331.0,
#   'average': 329.5674194876016,
#   'aomVolume': 3887600.0,
#   'aomValue': 1281226300.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 3890150.0,
#   'totalValue': 1282065132.0,
#   'pe': 18.58,
#   'pbv': 1.06,
#   'bvps': 311.88,
#   'dividendYield': 2.4200000762939453,
#   'marketCap': 397200000000.0,
#   'volumeTurnover': 0.3241791666666667},
#  {'date': '2023-03-09',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 331.0,
#   'open': 331.0,
#   'high': 332.0,
#   'low': 330.0,
#   'close': 331.0,
#   'average': 331.45405125550093,
#   'aomVolume': 1545200.0,
#   'aomValue': 512162800.0,
#   'trVolume': 800.0,
#   'trValue': 264800.0,
#   'totalVolume': 1546721.0,
#   'totalValue': 512666270.0,
#   'pe': 18.58,
#   'pbv': 1.06,
#   'bvps': 311.88,
#   'dividendYield': 2.4200000762939453,
#   'marketCap': 397200000000.0,
#   'volumeTurnover': 0.12889341666666668},
#  {'date': '2023-03-10',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 331.0,
#   'open': 330.0,
#   'high': 331.0,
#   'low': 328.0,
#   'close': 331.0,
#   'average': 329.9527694678633,
#   'aomVolume': 1103100.0,
#   'aomValue': 363970900.0,
#   'trVolume': 75200.0,
#   'trValue': 24816075.2,
#   'totalVolume': 1179284.0,
#   'totalValue': 389111307.2,
#   'pe': 18.58,
#   'pbv': 1.06,
#   'bvps': 311.88,
#   'dividendYield': 2.4200000762939453,
#   'marketCap': 397200000000.0,
#   'volumeTurnover': 0.09827366666666666},
#  {'date': '2023-03-13',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 331.0,
#   'open': 330.0,
#   'high': 332.0,
#   'low': 328.0,
#   'close': 329.0,
#   'average': 330.0915660265294,
#   'aomVolume': 2020400.0,
#   'aomValue': 666917000.0,
#   'trVolume': 2900.0,
#   'trValue': 954100.0,
#   'totalVolume': 2024557.0,
#   'totalValue': 668286032.0,
#   'pe': 18.46,
#   'pbv': 1.05,
#   'bvps': 311.88,
#   'dividendYield': 2.430000066757202,
#   'marketCap': 394800000000.0,
#   'volumeTurnover': 0.16871308333333335},
#  {'date': '2023-03-14',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 329.0,
#   'open': 328.0,
#   'high': 329.0,
#   'low': 316.0,
#   'close': 316.0,
#   'average': 320.8391391967756,
#   'aomVolume': 4168200.0,
#   'aomValue': 1337321700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 4175360.0,
#   'totalValue': 1339616839.0,
#   'pe': 17.73,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5299999713897705,
#   'marketCap': 379200000000.0,
#   'volumeTurnover': 0.3479466666666667},
#  {'date': '2023-03-15',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 316.0,
#   'open': 322.0,
#   'high': 326.0,
#   'low': 321.0,
#   'close': 323.0,
#   'average': 323.0487158315588,
#   'aomVolume': 2301100.0,
#   'aomValue': 743367400.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2302398.0,
#   'totalValue': 743786805.0,
#   'pe': 18.13,
#   'pbv': 1.04,
#   'bvps': 311.88,
#   'dividendYield': 2.4800000190734863,
#   'marketCap': 387600000000.0,
#   'volumeTurnover': 0.1918665},
#  {'date': '2023-03-16',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 323.0,
#   'open': 320.0,
#   'high': 321.0,
#   'low': 315.0,
#   'close': 318.0,
#   'average': 317.06932998263056,
#   'aomVolume': 2705900.0,
#   'aomValue': 857957900.0,
#   'trVolume': 200.0,
#   'trValue': 63600.0,
#   'totalVolume': 2709002.0,
#   'totalValue': 858942943.0,
#   'pe': 17.85,
#   'pbv': 1.02,
#   'bvps': 311.88,
#   'dividendYield': 2.5199999809265137,
#   'marketCap': 381600000000.0,
#   'volumeTurnover': 0.22575016666666667},
#  {'date': '2023-03-17',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 318.0,
#   'open': 320.0,
#   'high': 320.0,
#   'low': 313.0,
#   'close': 315.0,
#   'average': 315.7122025170248,
#   'aomVolume': 4155700.0,
#   'aomValue': 1312005200.0,
#   'trVolume': 100.0,
#   'trValue': 31500.0,
#   'totalVolume': 4160480.0,
#   'totalValue': 1313516026.0,
#   'pe': 17.68,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5399999618530273,
#   'marketCap': 378000000000.0,
#   'volumeTurnover': 0.346763},
#  {'date': '2023-03-20',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 315.0,
#   'open': 313.0,
#   'high': 316.0,
#   'low': 311.0,
#   'close': 315.0,
#   'average': 314.0278138809462,
#   'aomVolume': 2308200.0,
#   'aomValue': 724839000.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2311337.0,
#   'totalValue': 725824274.0,
#   'pe': 17.68,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5399999618530273,
#   'marketCap': 378000000000.0,
#   'volumeTurnover': 0.19261141666666667},
#  {'date': '2023-03-21',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 315.0,
#   'open': 317.0,
#   'high': 320.0,
#   'low': 315.0,
#   'close': 320.0,
#   'average': 318.1847263470513,
#   'aomVolume': 1178500.0,
#   'aomValue': 374980700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1179841.0,
#   'totalValue': 375406561.0,
#   'pe': 17.96,
#   'pbv': 1.03,
#   'bvps': 311.88,
#   'dividendYield': 2.5,
#   'marketCap': 384000000000.0,
#   'volumeTurnover': 0.09832008333333334},
#  {'date': '2023-03-22',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 320.0,
#   'open': 321.0,
#   'high': 322.0,
#   'low': 318.0,
#   'close': 321.0,
#   'average': 320.2963311382879,
#   'aomVolume': 850400.0,
#   'aomValue': 272380000.0,
#   'trVolume': 43500.0,
#   'trValue': 13963500.0,
#   'totalVolume': 894894.0,
#   'totalValue': 286661882.0,
#   'pe': 18.01,
#   'pbv': 1.03,
#   'bvps': 311.88,
#   'dividendYield': 2.490000009536743,
#   'marketCap': 385200000000.0,
#   'volumeTurnover': 0.0745745},
#  {'date': '2023-03-23',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 321.0,
#   'open': 318.0,
#   'high': 323.0,
#   'low': 318.0,
#   'close': 322.0,
#   'average': 321.15433934212973,
#   'aomVolume': 1076200.0,
#   'aomValue': 345626300.0,
#   'trVolume': 30000.0,
#   'trValue': 9660000.0,
#   'totalVolume': 1107107.0,
#   'totalValue': 355577533.0,
#   'pe': 18.07,
#   'pbv': 1.03,
#   'bvps': 311.88,
#   'dividendYield': 2.4800000190734863,
#   'marketCap': 386400000000.0,
#   'volumeTurnover': 0.09225891666666666},
#  {'date': '2023-03-24',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 322.0,
#   'open': 322.0,
#   'high': 322.0,
#   'low': 318.0,
#   'close': 319.0,
#   'average': 319.5758765978719,
#   'aomVolume': 1400300.0,
#   'aomValue': 447502100.0,
#   'trVolume': 226400.0,
#   'trValue': 72373672.88,
#   'totalVolume': 1628404.0,
#   'totalValue': 520419703.88,
#   'pe': 17.9,
#   'pbv': 1.02,
#   'bvps': 311.88,
#   'dividendYield': 2.509999990463257,
#   'marketCap': 382800000000.0,
#   'volumeTurnover': 0.13570033333333334},
#  {'date': '2023-03-27',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 319.0,
#   'open': 321.0,
#   'high': 321.0,
#   'low': 319.0,
#   'close': 319.0,
#   'average': 319.8118401987166,
#   'aomVolume': 483100.0,
#   'aomValue': 154501100.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 483783.0,
#   'totalValue': 154719663.0,
#   'pe': 17.9,
#   'pbv': 1.02,
#   'bvps': 311.88,
#   'dividendYield': 2.509999990463257,
#   'marketCap': 382800000000.0,
#   'volumeTurnover': 0.04031525},
#  {'date': '2023-03-28',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 319.0,
#   'open': 320.0,
#   'high': 321.0,
#   'low': 318.0,
#   'close': 320.0,
#   'average': 319.5673899755501,
#   'aomVolume': 1308800.0,
#   'aomValue': 418249800.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1309945.0,
#   'totalValue': 418615710.0,
#   'pe': 17.96,
#   'pbv': 1.03,
#   'bvps': 311.88,
#   'dividendYield': 2.5,
#   'marketCap': 384000000000.0,
#   'volumeTurnover': 0.10916208333333334},
#  {'date': '2023-03-29',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 320.0,
#   'open': 321.0,
#   'high': 321.0,
#   'low': 319.0,
#   'close': 321.0,
#   'average': 320.34045718923306,
#   'aomVolume': 739300.0,
#   'aomValue': 236827700.0,
#   'trVolume': 3100.0,
#   'trValue': 995100.0,
#   'totalVolume': 743344.0,
#   'totalValue': 238125588.0,
#   'pe': 18.01,
#   'pbv': 1.03,
#   'bvps': 311.88,
#   'dividendYield': 2.490000009536743,
#   'marketCap': 385200000000.0,
#   'volumeTurnover': 0.06194533333333333},
#  {'date': '2023-03-30',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 321.0,
#   'open': 321.0,
#   'high': 321.0,
#   'low': 315.0,
#   'close': 315.0,
#   'average': 317.0390259296271,
#   'aomVolume': 1901300.0,
#   'aomValue': 602786300.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1904199.0,
#   'totalValue': 603707646.0,
#   'pe': 17.68,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5399999618530273,
#   'marketCap': 378000000000.0,
#   'volumeTurnover': 0.15868325},
#  {'date': '2023-03-31',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 315.0,
#   'open': 315.0,
#   'high': 317.0,
#   'low': 315.0,
#   'close': 315.0,
#   'average': 315.65239508266217,
#   'aomVolume': 943600.0,
#   'aomValue': 297849600.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 945159.0,
#   'totalValue': 298342791.0,
#   'pe': 17.68,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5399999618530273,
#   'marketCap': 378000000000.0,
#   'volumeTurnover': 0.07876325},
#  {'date': '2023-04-03',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 315.0,
#   'open': 316.0,
#   'high': 318.0,
#   'low': 314.0,
#   'close': 317.0,
#   'average': 315.91572406088534,
#   'aomVolume': 1432200.0,
#   'aomValue': 452454500.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1434565.0,
#   'totalValue': 453201298.0,
#   'pe': 17.79,
#   'pbv': 1.02,
#   'bvps': 311.88,
#   'dividendYield': 2.5199999809265137,
#   'marketCap': 380400000000.0,
#   'volumeTurnover': 0.11954708333333333},
#  {'date': '2023-04-04',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 317.0,
#   'open': 319.0,
#   'high': 319.0,
#   'low': 314.0,
#   'close': 315.0,
#   'average': 315.29421984630807,
#   'aomVolume': 1496500.0,
#   'aomValue': 471837800.0,
#   'trVolume': 10900.0,
#   'trValue': 3433500.0,
#   'totalVolume': 1508950.0,
#   'totalValue': 475760552.0,
#   'pe': 17.68,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5399999618530273,
#   'marketCap': 378000000000.0,
#   'volumeTurnover': 0.12574583333333333},
#  {'date': '2023-04-05',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 315.0,
#   'open': 314.0,
#   'high': 316.0,
#   'low': 313.0,
#   'close': 315.0,
#   'average': 314.60511243105645,
#   'aomVolume': 942800.0,
#   'aomValue': 296609700.0,
#   'trVolume': 100.0,
#   'trValue': 31500.0,
#   'totalVolume': 944503.0,
#   'totalValue': 297146564.0,
#   'pe': 17.68,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5399999618530273,
#   'marketCap': 378000000000.0,
#   'volumeTurnover': 0.07870858333333333},
#  {'date': '2023-04-07',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 315.0,
#   'open': 314.0,
#   'high': 315.0,
#   'low': 312.0,
#   'close': 312.0,
#   'average': 313.29995196926035,
#   'aomVolume': 832800.0,
#   'aomValue': 260916200.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 834718.0,
#   'totalValue': 261518682.0,
#   'pe': 17.51,
#   'pbv': 1.0,
#   'bvps': 311.88,
#   'dividendYield': 2.559999942779541,
#   'marketCap': 374400000000.0,
#   'volumeTurnover': 0.06955983333333333},
#  {'date': '2023-04-10',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 312.0,
#   'open': 313.0,
#   'high': 316.0,
#   'low': 313.0,
#   'close': 314.0,
#   'average': 314.41320680110715,
#   'aomVolume': 758700.0,
#   'aomValue': 238545300.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 759510.0,
#   'totalValue': 238800136.0,
#   'pe': 17.62,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.549999952316284,
#   'marketCap': 376800000000.0,
#   'volumeTurnover': 0.0632925},
#  {'date': '2023-04-11',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 314.0,
#   'open': 315.0,
#   'high': 316.0,
#   'low': 311.0,
#   'close': 312.0,
#   'average': 312.43676300578034,
#   'aomVolume': 1297500.0,
#   'aomValue': 405386700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1300258.0,
#   'totalValue': 406249910.0,
#   'pe': 17.51,
#   'pbv': 1.0,
#   'bvps': 311.88,
#   'dividendYield': 2.559999942779541,
#   'marketCap': 374400000000.0,
#   'volumeTurnover': 0.10835483333333333},
#  {'date': '2023-04-12',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 312.0,
#   'open': 312.0,
#   'high': 316.0,
#   'low': 311.0,
#   'close': 316.0,
#   'average': 313.63772968558595,
#   'aomVolume': 1224500.0,
#   'aomValue': 384049400.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1225819.0,
#   'totalValue': 384463020.0,
#   'pe': 17.73,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5299999713897705,
#   'marketCap': 379200000000.0,
#   'volumeTurnover': 0.10215158333333334},
#  {'date': '2023-04-17',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 316.0,
#   'open': 317.0,
#   'high': 317.0,
#   'low': 312.0,
#   'close': 315.0,
#   'average': 314.51202373516554,
#   'aomVolume': 1280800.0,
#   'aomValue': 402827000.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1282401.0,
#   'totalValue': 403330762.0,
#   'pe': 17.68,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5399999618530273,
#   'marketCap': 378000000000.0,
#   'volumeTurnover': 0.10686675},
#  {'date': '2023-04-18',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 315.0,
#   'open': 315.0,
#   'high': 315.0,
#   'low': 312.0,
#   'close': 312.0,
#   'average': 313.25696933492634,
#   'aomVolume': 1004400.0,
#   'aomValue': 314635300.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1005590.0,
#   'totalValue': 315008010.0,
#   'pe': 17.51,
#   'pbv': 1.0,
#   'bvps': 311.88,
#   'dividendYield': 2.559999942779541,
#   'marketCap': 374400000000.0,
#   'volumeTurnover': 0.08379916666666666},
#  {'date': '2023-04-19',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 312.0,
#   'open': 311.0,
#   'high': 312.0,
#   'low': 308.0,
#   'close': 309.0,
#   'average': 310.179745904653,
#   'aomVolume': 2447900.0,
#   'aomValue': 759289000.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2451637.0,
#   'totalValue': 760449235.0,
#   'pe': 17.34,
#   'pbv': 0.99,
#   'bvps': 311.88,
#   'dividendYield': 2.5899999141693115,
#   'marketCap': 370800000000.0,
#   'volumeTurnover': 0.20430308333333333},
#  {'date': '2023-04-20',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 309.0,
#   'open': 311.0,
#   'high': 312.0,
#   'low': 305.0,
#   'close': 305.0,
#   'average': 307.0658861965696,
#   'aomVolume': 1836500.0,
#   'aomValue': 563926500.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1841381.0,
#   'totalValue': 565428878.0,
#   'pe': 17.12,
#   'pbv': 0.98,
#   'bvps': 311.88,
#   'dividendYield': 2.619999885559082,
#   'marketCap': 366000000000.0,
#   'volumeTurnover': 0.15344841666666667},
#  {'date': '2023-04-21',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 305.0,
#   'open': 305.0,
#   'high': 307.0,
#   'low': 301.0,
#   'close': 304.0,
#   'average': 303.3557071807308,
#   'aomVolume': 2432900.0,
#   'aomValue': 738034100.0,
#   'trVolume': 100.0,
#   'trValue': 30400.0,
#   'totalVolume': 2439089.0,
#   'totalValue': 739916327.0,
#   'pe': 17.06,
#   'pbv': 0.97,
#   'bvps': 311.88,
#   'dividendYield': 2.630000114440918,
#   'marketCap': 364800000000.0,
#   'volumeTurnover': 0.20325741666666666},
#  {'date': '2023-04-24',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 304.0,
#   'open': 305.0,
#   'high': 306.0,
#   'low': 302.0,
#   'close': 305.0,
#   'average': 303.5292843783837,
#   'aomVolume': 1015900.0,
#   'aomValue': 308355400.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1017385.0,
#   'totalValue': 308806453.0,
#   'pe': 17.12,
#   'pbv': 0.98,
#   'bvps': 311.88,
#   'dividendYield': 2.619999885559082,
#   'marketCap': 366000000000.0,
#   'volumeTurnover': 0.08478208333333333},
#  {'date': '2023-04-25',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 305.0,
#   'open': 304.0,
#   'high': 305.0,
#   'low': 300.0,
#   'close': 303.0,
#   'average': 301.7192846835704,
#   'aomVolume': 1940400.0,
#   'aomValue': 585456100.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1943522.0,
#   'totalValue': 586398802.0,
#   'pe': 17.0,
#   'pbv': 0.97,
#   'bvps': 311.88,
#   'dividendYield': 2.640000104904175,
#   'marketCap': 363600000000.0,
#   'volumeTurnover': 0.16196016666666666},
#  {'date': '2023-04-26',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 303.0,
#   'open': 304.0,
#   'high': 304.0,
#   'low': 301.0,
#   'close': 301.0,
#   'average': 301.6913748795374,
#   'aomVolume': 1245200.0,
#   'aomValue': 375666100.0,
#   'trVolume': 3200.0,
#   'trValue': 963200.0,
#   'totalVolume': 1250228.0,
#   'totalValue': 377181708.0,
#   'pe': 16.89,
#   'pbv': 0.97,
#   'bvps': 311.88,
#   'dividendYield': 2.6600000858306885,
#   'marketCap': 361200000000.0,
#   'volumeTurnover': 0.10418566666666666},
#  {'date': '2023-04-27',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 301.0,
#   'open': 306.0,
#   'high': 313.0,
#   'low': 306.0,
#   'close': 311.0,
#   'average': 310.84543499834604,
#   'aomVolume': 4836800.0,
#   'aomValue': 1503497200.0,
#   'trVolume': 175000.0,
#   'trValue': 54401037.0,
#   'totalVolume': 5014911.0,
#   'totalValue': 1558864724.0,
#   'pe': 17.45,
#   'pbv': 1.0,
#   'bvps': 311.88,
#   'dividendYield': 2.569999933242798,
#   'marketCap': 373200000000.0,
#   'volumeTurnover': 0.41790925},
#  {'date': '2023-04-28',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 311.0,
#   'open': 312.0,
#   'high': 314.0,
#   'low': 308.0,
#   'close': 314.0,
#   'average': 311.92862305746297,
#   'aomVolume': 2213600.0,
#   'aomValue': 690485200.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 2214943.0,
#   'totalValue': 690903114.0,
#   'pe': 17.62,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.549999952316284,
#   'marketCap': 376800000000.0,
#   'volumeTurnover': 0.18457858333333332},
#  {'date': '2023-05-02',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 314.0,
#   'open': 315.0,
#   'high': 316.0,
#   'low': 312.0,
#   'close': 316.0,
#   'average': 314.1157103352921,
#   'aomVolume': 1157200.0,
#   'aomValue': 363494700.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 1158551.0,
#   'totalValue': 363918311.0,
#   'pe': 17.73,
#   'pbv': 1.01,
#   'bvps': 311.88,
#   'dividendYield': 2.5299999713897705,
#   'marketCap': 379200000000.0,
#   'volumeTurnover': 0.09654591666666666},
#  {'date': '2023-05-03',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 316.0,
#   'open': 318.0,
#   'high': 327.0,
#   'low': 314.0,
#   'close': 325.0,
#   'average': 320.21092443665896,
#   'aomVolume': 5023600.0,
#   'aomValue': 1608611600.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 5027718.0,
#   'totalValue': 1609931330.0,
#   'pe': 18.24,
#   'pbv': 1.04,
#   'bvps': 311.88,
#   'dividendYield': 2.4600000381469727,
#   'marketCap': 390000000000.0,
#   'volumeTurnover': 0.4189765},
#  {'date': '2023-05-08',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 325.0,
#   'open': 332.0,
#   'high': 335.0,
#   'low': 329.0,
#   'close': 335.0,
#   'average': 332.81588174630457,
#   'aomVolume': 4363500.0,
#   'aomValue': 1452242100.0,
#   'trVolume': None,
#   'trValue': None,
#   'totalVolume': 4366726.0,
#   'totalValue': 1453312505.0,
#   'pe': 18.8,
#   'pbv': 1.07,
#   'bvps': 311.88,
#   'dividendYield': 2.390000104904175,
#   'marketCap': 402000000000.0,
#   'volumeTurnover': 0.36389383333333336},
#  {'date': '2023-05-09',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 335.0,
#   'open': 334.0,
#   'high': 335.0,
#   'low': 331.0,
#   'close': 334.0,
#   'average': 332.87705761316874,
#   'aomVolume': 2138400.0,
#   'aomValue': 711824300.0,
#   'trVolume': 60100.0,
#   'trValue': 20013400.0,
#   'totalVolume': 2199887.0,
#   'totalValue': 732298998.0,
#   'pe': 18.74,
#   'pbv': 1.07,
#   'bvps': 311.88,
#   'dividendYield': 2.4000000953674316,
#   'marketCap': 400800000000.0,
#   'volumeTurnover': 0.18332391666666667},
#  {'date': '2023-05-10',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 334.0,
#   'open': 330.0,
#   'high': 335.0,
#   'low': 330.0,
#   'close': 334.0,
#   'average': 332.70091458522757,
#   'aomVolume': 1869700.0,
#   'aomValue': 622050900.0,
#   'trVolume': 0.0,
#   'trValue': 0.0,
#   'totalVolume': 1870812.0,
#   'totalValue': 622420387.0,
#   'pe': 18.74,
#   'pbv': 1.07,
#   'bvps': 311.88,
#   'dividendYield': 2.4000000953674316,
#   'marketCap': 400800000000.0,
#   'volumeTurnover': 0.155901},
#  {'date': '2023-05-11',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 334.0,
#   'open': 334.0,
#   'high': 334.0,
#   'low': 331.0,
#   'close': 334.0,
#   'average': 332.9647908822632,
#   'aomVolume': 982700.0,
#   'aomValue': 327204500.0,
#   'trVolume': 0.0,
#   'trValue': 0.0,
#   'totalVolume': 983494.0,
#   'totalValue': 327468500.0,
#   'pe': 18.74,
#   'pbv': 1.07,
#   'bvps': 311.88,
#   'dividendYield': 2.4000000953674316,
#   'marketCap': 400800000000.0,
#   'volumeTurnover': 0.08195783333333333},
#  {'date': '2023-05-12',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 334.0,
#   'open': 334.0,
#   'high': 337.0,
#   'low': 332.0,
#   'close': 336.0,
#   'average': 335.0256679807271,
#   'aomVolume': 2283000.0,
#   'aomValue': 764863600.0,
#   'trVolume': 100.0,
#   'trValue': 33600.0,
#   'totalVolume': 2284974.0,
#   'totalValue': 765525140.0,
#   'pe': 18.86,
#   'pbv': 1.08,
#   'bvps': 311.88,
#   'dividendYield': 2.380000114440918,
#   'marketCap': 403200000000.0,
#   'volumeTurnover': 0.1904145},
#  {'date': '2023-05-15',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 336.0,
#   'open': 338.0,
#   'high': 338.0,
#   'low': 333.0,
#   'close': 333.0,
#   'average': 335.5130203822392,
#   'aomVolume': 1731900.0,
#   'aomValue': 581075000.0,
#   'trVolume': 0.0,
#   'trValue': 0.0,
#   'totalVolume': 1732983.0,
#   'totalValue': 581438606.0,
#   'pe': 18.69,
#   'pbv': 1.07,
#   'bvps': 311.88,
#   'dividendYield': 2.4000000953674316,
#   'marketCap': 399600000000.0,
#   'volumeTurnover': 0.14441525},
#  {'date': '2023-05-16',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 333.0,
#   'open': 335.0,
#   'high': 339.0,
#   'low': 334.0,
#   'close': 337.0,
#   'average': 336.48937007874014,
#   'aomVolume': 1778000.0,
#   'aomValue': 598278100.0,
#   'trVolume': 100.0,
#   'trValue': 33700.0,
#   'totalVolume': 1779653.0,
#   'totalValue': 598834289.0,
#   'pe': 13.91,
#   'pbv': 1.04,
#   'bvps': 322.87,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 404400000000.0,
#   'volumeTurnover': 0.14830441666666666},
#  {'date': '2023-05-17',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 337.0,
#   'open': 337.0,
#   'high': 340.0,
#   'low': 335.0,
#   'close': 339.0,
#   'average': 337.6279390257622,
#   'aomVolume': 3555600.0,
#   'aomValue': 1200469900.0,
#   'trVolume': 0.0,
#   'trValue': 0.0,
#   'totalVolume': 3557162.0,
#   'totalValue': 1200997012.0,
#   'pe': 14.0,
#   'pbv': 1.05,
#   'bvps': 322.87,
#   'dividendYield': 2.359999895095825,
#   'marketCap': 406800000000.0,
#   'volumeTurnover': 0.29643016666666666},
#  {'date': '2023-05-18',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 339.0,
#   'open': 340.0,
#   'high': 340.0,
#   'low': 336.0,
#   'close': 339.0,
#   'average': 337.88021473384646,
#   'aomVolume': 1546100.0,
#   'aomValue': 522396600.0,
#   'trVolume': 100000.0,
#   'trValue': 33800000.0,
#   'totalVolume': 1646807.0,
#   'totalValue': 556435362.0,
#   'pe': 14.0,
#   'pbv': 1.05,
#   'bvps': 322.87,
#   'dividendYield': 2.359999895095825,
#   'marketCap': 406800000000.0,
#   'volumeTurnover': 0.13723391666666668},
#  {'date': '2023-05-19',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 339.0,
#   'open': 339.0,
#   'high': 339.0,
#   'low': 336.0,
#   'close': 339.0,
#   'average': 337.7000955109838,
#   'aomVolume': 1570500.0,
#   'aomValue': 530358000.0,
#   'trVolume': 0.0,
#   'trValue': 0.0,
#   'totalVolume': 1571653.0,
#   'totalValue': 530746479.0,
#   'pe': 14.0,
#   'pbv': 1.05,
#   'bvps': 322.87,
#   'dividendYield': 2.359999895095825,
#   'marketCap': 406800000000.0,
#   'volumeTurnover': 0.13097108333333332},
#  {'date': '2023-05-22',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 339.0,
#   'open': 335.0,
#   'high': 336.0,
#   'low': 331.0,
#   'close': 336.0,
#   'average': 334.1129766901849,
#   'aomVolume': 2239400.0,
#   'aomValue': 748212600.0,
#   'trVolume': 0.0,
#   'trValue': 0.0,
#   'totalVolume': 2240649.0,
#   'totalValue': 748629203.0,
#   'pe': 13.87,
#   'pbv': 1.04,
#   'bvps': 322.87,
#   'dividendYield': 2.380000114440918,
#   'marketCap': 403200000000.0,
#   'volumeTurnover': 0.18672075},
#  {'date': '2023-05-23',
#   'symbol': 'SCC',
#   'securityType': 'CS',
#   'adjustedPriceFlag': 'Y',
#   'prior': 336.0,
#   'open': 335.0,
#   'high': 339.0,
#   'low': 333.0,
#   'close': 337.0,
#   'average': 336.15034535686874,
#   'aomVolume': 1303000.0,
#   'aomValue': 438003900.0,
#   'trVolume': 100.0,
#   'trValue': 33700.0,
#   'totalVolume': 1303777.0,
#   'totalValue': 438265556.0,
#   'pe': 13.91,
#   'pbv': 1.04,
#   'bvps': 322.87,
#   'dividendYield': 2.369999885559082,
#   'marketCap': 404400000000.0,
#   'volumeTurnover': 0.10864808333333334}]

# %%
pd.DataFrame(data_f)
# Out:
#           date symbol securityType adjustedPriceFlag  prior   open   high  \
# 0   2023-01-03    SCC           CS                 Y  342.0  341.0  344.0
# 1   2023-01-04    SCC           CS                 Y  342.0  342.0  345.0
# 2   2023-01-05    SCC           CS                 Y  345.0  345.0  350.0
# 3   2023-01-06    SCC           CS                 Y  349.0  349.0  351.0
# 4   2023-01-09    SCC           CS                 Y  350.0  353.0  354.0
# ..         ...    ...          ...               ...    ...    ...    ...
# 89  2023-05-17    SCC           CS                 Y  337.0  337.0  340.0
# 90  2023-05-18    SCC           CS                 Y  339.0  340.0  340.0
# 91  2023-05-19    SCC           CS                 Y  339.0  339.0  339.0
# 92  2023-05-22    SCC           CS                 Y  339.0  335.0  336.0
# 93  2023-05-23    SCC           CS                 Y  336.0  335.0  339.0
#
#       low  close     average  ...  trVolume     trValue  totalVolume  \
# 0   340.0  342.0  342.059286  ...       NaN         NaN    1667649.0
# 1   340.0  345.0  343.080090  ...       NaN         NaN    1560548.0
# 2   344.0  349.0  348.151706  ...   10900.0   4051366.5    2747959.0
# 3   347.0  350.0  349.795692  ...       NaN         NaN    1473891.0
# 4   351.0  352.0  352.583638  ...       NaN         NaN    1640824.0
# ..    ...    ...         ...  ...       ...         ...          ...
# 89  335.0  339.0  337.627939  ...       0.0         0.0    3557162.0
# 90  336.0  339.0  337.880215  ...  100000.0  33800000.0    1646807.0
# 91  336.0  339.0  337.700096  ...       0.0         0.0    1571653.0
# 92  331.0  336.0  334.112977  ...       0.0         0.0    2240649.0
# 93  333.0  337.0  336.150345  ...     100.0     33700.0    1303777.0
#
#       totalValue     pe   pbv    bvps  dividendYield     marketCap  \
# 0   5.704349e+08  13.90  1.04  329.61           5.41  4.104000e+11
# 1   5.353922e+08  14.02  1.05  329.61           5.36  4.140000e+11
# 2   9.569624e+08  14.18  1.06  329.61           5.30  4.188000e+11
# 3   5.155609e+08  14.22  1.06  329.61           5.29  4.200000e+11
# 4   5.785278e+08  14.30  1.07  329.61           5.26  4.224000e+11
# ..           ...    ...   ...     ...            ...           ...
# 89  1.200997e+09  14.00  1.05  322.87           2.36  4.068000e+11
# 90  5.564354e+08  14.00  1.05  322.87           2.36  4.068000e+11
# 91  5.307465e+08  14.00  1.05  322.87           2.36  4.068000e+11
# 92  7.486292e+08  13.87  1.04  322.87           2.38  4.032000e+11
# 93  4.382656e+08  13.91  1.04  322.87           2.37  4.044000e+11
#
#     volumeTurnover
# 0         0.138971
# 1         0.130046
# 2         0.228997
# 3         0.122824
# 4         0.136735
# ..             ...
# 89        0.296430
# 90        0.137234
# 91        0.130971
# 92        0.186721
# 93        0.108648
#
# [94 rows x 22 columns]

# %%
# https://www.setsmart.com/ism/tfexSeriesTrading.html?showEndDate=30%2F03%2F2023&decorator=excel&endDate=30%2F03%2F2023&lstDisplay=T&seriesId=109966&submit.x=25&lstPeriod=D&submit.y=11&periodView=A&strLastTradeDate=23%2F06%2F2023&beginDate=2%2F01%2F2023&tradingMethod=&series=SCCH23&showBeginDate=2%2F01%2F2023&strFirstTradeDate=28%2F04%2F2006&allTradingDate=false
end_date = '30/03/2023'
beginDate = '2/01/2023'
series_id = '109966'
series = 'SCCH23'
period_view = 'A'

params = {
    'showEndDate': end_date,
    'decorator': 'excel',
    'endDate': end_date,
    'lstDisplay': 'T',
    'seriesId': series_id,
    'submit.x': '25',
    'lstPeriod': 'D',
    'submit.y': '11',
    'periodView': period_view,
    'strLastTradeDate': '23/06/2023',
    'beginDate': beginDate,
    'tradingMethod': '',
    'series': series,
    'showBeginDate': beginDate,
    'strFirstTradeDate': '28/04/2006',
    'allTradingDate': 'false'
}
#convert  / to %2F
params = {k: v.replace('/', '%2F') for k, v in params.items()}
